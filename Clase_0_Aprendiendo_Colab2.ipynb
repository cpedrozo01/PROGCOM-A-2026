# %% [markdown]
# <a href="https://colab.research.google.com/github/cpedrozo01/PROGCOM-A-2026/blob/main/Clase_0_Aprendiendo_Colab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bienvenida
# ##Aprendiendo a usar print
# Print() es un método que permite imprimir infromación en consola
#
# Sintaxis
#
# ```
# if (condicion)==verdadera
#   print("Pasan cositas")
# else:
#   print("Pasan otras cositas")
# ```
# El print() puede imprimir lo siguiente:
# 1. Cualquier tipo de dato
# 2. Cualquier método o función (su dirección en memoria)
# 3. Concantenación de texto
# 4. Operaciones matemáticas

# %% [markdown]
# ##Conociendo el input
# input() es un método con triple función
# * Declara: toda la información que ingresa con este método, se declara automáticamente como string (caracter).
# * lee: Porque almacena en una variable
# * imprime: Porque lo que está entre los paréntesis, se visualiza en consola

# %%
a=24
b=50
a+b

# %% [markdown]
# ###Concatenación
# Concatenar es unir dos tipos diferentes de datos

# %%
x=int(input("Ingrese su edad:"))
y=input("Ingrese su nombre:")
#Ejemplo 1
print(y, "tiene una edad de",x)
# Out:
# Ingrese su edad:21
# Ingrese su nombre:Cristian
# Cristian tiene una edad de 21

# %%
#Ejemplo 2
print(y+" tiene una edad de "+str(x))
# Out:
# Cristian tiene una edad de 21

# %%
#Ejemplo 3
print(f"{y} tiene una edad de {x}")
# Out:
# Cristian tiene una edad de 21
